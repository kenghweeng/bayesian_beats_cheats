# %%
import pandas as pd
import os
import io
import re
from tqdm import tqdm
import pickle
import math

# %%
# folder_directory = '/Users/leonard.lee/Downloads/CS5340_Project/moss'
folder_directory = '/Users/juliet/leonard_tmp/CS5340_Project/moss'
file_name = '1821_1935_2023.csv'

moss_folder = os.path.join(folder_directory, file_name)

# %%
moss_data = pd.read_csv(moss_folder)

# %%
moss_data.sample(10)
# Out:
#                                   mission  cohort1  assessment1  submission1  \
# 2871                     more_than_thrice     1821        33158       885798
# 4109                          diagnostics     1935        38699      1052601
# 3982                          rogue_train     1821        33192       900806
# 249   dna_using_data_directed_programming     1935        39561      1085100
# 1930                       3_station_ippt     2023        41926      1173138
# 3087                         rune_reading     1821        33200       868590
# 4                         beautiful_runes     1935        38713      1027426
# 4037                          diagnostics     1821        33198       898991
# 2037                            dragonize     1935        38704      1048129
# 1035                           lazy_susan     1821        33173       896469
#
#                  name1  cohort2  assessment2  submission2              name2  \
# 2871      james_turner     1935        38712      1036025     crystal_conley
# 4109  rebecca_crawford     1935        38699      1052588      chelsea_smith
# 3982       stacy_brown     1935        38693      1067108   jordan_alexander
# 249     laura_phillips     1935        39561      1080706      michael_brown
# 1930      mason_deleon     2023        41926      1176920       jose_kennedy
# 3087   jessica_huffman     1935        38701      1012698        keith_scott
# 4     joshua_hernandez     1935        38713      1026134       carol_harris
# 4037   susan_davis_phd     2023        41920      1162743  christian_jackson
# 2037       jesse_perry     1935        38704      1043002      anne_thompson
# 1035      marcus_moore     1935        38724      1055345      lindsay_rocha
#
#       percent1  percent2  lines  \
# 2871        33        32     22
# 4109        31        34     12
# 3982        28        27     84
# 249         41        36     31
# 1930        29        25     23
# 3087        72        91     44
# 4           51        47     12
# 4037        49        59     28
# 2037        65        72      7
# 1035        44        10     61
#
#                                                     url
# 2871  http://moss.stanford.edu/results/3/69248926195...
# 4109  http://moss.stanford.edu/results/5/26685513583...
# 3982  http://moss.stanford.edu/results/7/61832847082...
# 249   http://moss.stanford.edu/results/0/10303382188...
# 1930  http://moss.stanford.edu/results/8/25409157187...
# 3087  http://moss.stanford.edu/results/8/89744940683...
# 4     http://moss.stanford.edu/results/1/88557058395...
# 4037  http://moss.stanford.edu/results/5/26685513583...
# 2037  http://moss.stanford.edu/results/9/40426497100...
# 1035  http://moss.stanford.edu/results/0/56645335735...

# %%
moss_data.shape
# Out:
# (4134, 13)

# %%
## Name to dict

all_names = set(moss_data.name1.tolist() + moss_data.name2.tolist())
name_to_ID = {name: i for i, name in enumerate(sorted(all_names))}
ID_to_name = {i: name for i, name in enumerate(sorted(all_names))}
name_ID_dict = {'all_names': all_names, 'name_to_ID': name_to_ID, 'ID_to_name': ID_to_name}

# %%
len(name_to_ID), name_to_ID['john_cuevas_md'], ID_to_name[476] ## Sanity Check
# Out:
# (1032, 476, 'john_cuevas_md')

# %%
pickle.dump(name_ID_dict, open('name_id_dict.pkl', 'wb'))

# %%
## Task 1 (edges)

moss_data = moss_data[moss_data['name1'] != moss_data['name2']]

# %%
import torch

unsorted_pairs = [(rows.name1, rows.name2) for _, rows in moss_data.iterrows() if rows.name1 != rows.name2]
pairs = []
for pair in unsorted_pairs:
    a = (pair[0], pair[1])
    b = (pair[1], pair[0])
    if a in pairs or b in pairs:
        continue
    else:
        pairs.append(pair)

sorted_pairs = sorted(set(pairs), key=lambda x: (name_to_ID[x[0]], name_to_ID[x[1]]))
tmp_s = list(map(lambda x: name_to_ID[x[0]], sorted_pairs))
tmp_t = list(map(lambda x: name_to_ID[x[1]], sorted_pairs))
src = []
for i, j in zip(tmp_s, tmp_t):
    src.append(i)
    src.append(j)
tgt = []
for i, j in zip(tmp_s, tmp_t):
    tgt.append(j)
    tgt.append(i)
edge_index = torch.tensor([src, tgt], dtype=torch.long)

# %%
## Get file lengths

def get_file_length(file_path, template_path):
    student_file = [line.strip() for line in io.open(file_path, 'r', encoding='utf-8') if line.strip() != '']
    template_file = [line.strip() for line in io.open(template_path, 'r', encoding='utf-8') if line.strip() != '']
    unique_lines = set(student_file).difference(set(template_file))
    return len(unique_lines)

lengths_dict = {'1821': {}, '1935': {}, '2023': {}}

# folder = '/Users/leonard.lee/Downloads/CS5340_Project/global_moss'
folder = '/Users/juliet/leonard_tmp/CS5340_Project/global_moss'
subfolders = moss_data['mission'].unique().tolist()
for path in tqdm(subfolders):
    jpath = os.path.join(folder, path)
    files = os.listdir(jpath)
    for file in files:
        if file.split('.')[0] in ['1821', '1935', '2023']:
            batch = file.split('.')[0]
            name = '.'.join(file.split('.')[3:-1])
            leng = get_file_length(os.path.join(jpath, file), os.path.join(folder, 'templates/{}.py'.format(path)))
            if path not in lengths_dict[batch]:
                lengths_dict[batch][path] = {}
            lengths_dict[batch][path][name] = leng
# Out:
# 100%|██████████| 28/28 [00:15<00:00,  1.77it/s]

# %%
lengths_dict['1935']['dna_using_data_directed_programming']['nathaniel_hood']
# Out:
# 42

# %%
## Standardise two percentages and extract rank

method_name = 'uniq_lines'

def standardise_method(name, percent1, percent2, offending_lines, names, batch, mission, leng_dic):
    if name == 'min':
        return min(percent1, percent2)
    elif name == 'max':
        return max(percent1, percent2)
    elif name == 'avg':
        return (percent1+percent2)/2
    elif name == 'uniq_lines':
        try:
            denom = min(leng_dic[str(batch[0])][mission][names[0]], leng_dic[str(batch[1])][mission][names[1]])
            return offending_lines/denom
        except:
            print(batch, mission, names)
            return 0

moss_data['standardised1'] = moss_data.apply(
    lambda x: standardise_method(method_name, x['percent1'], x['percent2'], 
                                 x['lines'], (x['name1'], x['name2']), 
                                 (x['cohort1'], x['cohort2']), x['mission'],
                                 lengths_dict),
    axis=1
)

pattern = re.compile(r'(match[0-9]+).html') ## Pattern to extract ranks
moss_data['Moss Rank'] = moss_data['url'].apply(lambda x: int(pattern.search(x)[0][5:-5]))
# Out:
# (2023, 2023) dna_using_data_directed_programming ('crystal_montgomery', 'carmen_lopez')
# (2023, 2023) dna_using_data_directed_programming ('sierra_montoya', 'carmen_lopez')
# (2023, 2023) dna_using_data_directed_programming ('sierra_montoya', 'crystal_montgomery')
# (1935, 2023) dna_using_data_directed_programming ('helen_mcdonald', 'nathaniel_hood')
# (1935, 2023) dna_using_data_directed_programming ('jamie_bennett', 'michael_stewart')
# (1935, 2023) dna_using_data_directed_programming ('christopher_marquez', 'michael_stewart')
# (1935, 2023) dna_using_data_directed_programming ('christopher_anderson', 'michael_stewart')
# (1935, 2023) dna_using_data_directed_programming ('steven_richards', 'michael_stewart')
# (1935, 2023) dna_using_data_directed_programming ('raymond_west', 'michael_stewart')
# (2023, 2023) dna_using_data_directed_programming ('john_cuevas_md', 'franklin_carlson')
# (1935, 2023) dna_using_data_directed_programming ('brittney_harding', 'jared_carter')
# (1935, 2023) dna_using_data_directed_programming ('antonio_cooper', 'micheal_humphrey')
# (1935, 2023) dna_using_data_directed_programming ('barry_dickerson', 'micheal_humphrey')
# (2023, 2023) dna_using_data_directed_programming ('alan_williams', 'franklin_carlson')
# (1935, 2023) dna_using_data_directed_programming ('laurie_wallace', 'jennifer_torres')
# (2023, 2023) dna_using_data_directed_programming ('alan_williams', 'john_cuevas_md')
# (2023, 2023) dna_using_data_directed_programming ('caitlin_reeves', 'nathaniel_hood')
# (1935, 2023) dna_using_data_directed_programming ('nathaniel_hood', 'caitlin_reeves')
# (1935, 2023) dna_using_data_directed_programming ('tiffany_perry', 'jennifer_torres')
# (1935, 2023) dna_using_data_directed_programming ('thomas_harris', 'michael_stewart')
# (2023, 2023) funky_merge_spell ('ricky_torres', 'teresa_bird')
# (1935, 2023) funky_merge_spell ('daniel_cox_dds', 'ricky_torres')
# (1935, 2023) funky_merge_spell ('molly_davis', 'ricky_torres')
# (2023, 2023) cheryl_s_birthday ('jacqueline_middleton', 'jennifer_washington')
# (1821, 2023) cheryl_s_birthday ('jennifer_summers', 'shannon_glover')
# (1935, 2023) lazy_susan ('jessica_smith', 'gregory_foster')
# (2023, 2023) lazy_susan ('gregory_foster', 'john_cuevas_md')
# (1935, 2023) lazy_susan ('angela_cordova', 'gregory_foster')
# (1935, 2023) lazy_susan ('john_cuevas_md', 'gregory_foster')
# (1935, 2023) lazy_susan ('patricia_baker', 'gregory_foster')
# (1935, 2023) dna_translation ('gary_snyder', 'larry_villarreal')
# (1935, 2023) dna_translation ('kara_medina', 'jennifer_li')
# (1935, 2023) dna_translation ('bryan_moore', 'brian_smith')
# (1935, 2023) dna_translation ('victoria_hubbard', 'edward_collier')
# (1935, 2023) dna_translation ('scott_hurst', 'jennifer_li')
# (1935, 2023) dna_translation ('jonathan_martin', 'jordan_green')
# (2023, 2023) dna_translation ('tonya_ellison', 'paula_thompson')
# (1935, 2023) dna_translation ('mary_sims', 'jennifer_li')
# (1935, 2023) dna_translation ('alex_perez', 'edward_collier')
# (1935, 2023) dna_translation ('carl_rollins', 'gary_brooks')
# (1935, 2023) dna_translation ('selena_navarro', 'timothy_tucker')
# (1935, 2023) dna_translation ('karen_mcdaniel', 'jimmy_moore')
# (1935, 2023) dna_translation ('lauren_casey', 'cody_torres')
# (1935, 2023) dna_translation ('micheal_sims', 'loretta_townsend')
# (1935, 2023) dna_translation ('jason_chapman', 'brian_smith')
# (1935, 2023) dna_translation ('patrick_ramsey', 'timothy_francis')
# (1935, 2023) dna_translation ('mrs._mary_johnson', 'haley_patrick')
# (1935, 2023) dna_translation ('steven_adams', 'haley_patrick')
# (2023, 2023) dna_translation ('jason_kelly', 'daisy_mcfarland')
# (1935, 2023) dna_translation ('kimberly_padilla', 'patricia_foster')
# (1935, 2023) dna_translation ('elizabeth_vaughn', 'jimmy_moore')
# (1935, 2023) dna_translation ('julie_mendoza', 'jason_kelly')
# (1935, 2023) dna_translation ('julie_mendoza', 'daisy_mcfarland')
# (2023, 2023) dna_translation ('rebecca_russo', 'harold_ryan')
# (1935, 2023) dna_translation ('vanessa_camacho', 'rebecca_russo')
# (1935, 2023) dna_translation ('vanessa_camacho', 'harold_ryan')
# (1935, 2023) dna_translation ('rebecca_crawford', 'haley_patrick')
# (2023, 2023) dna_translation ('cynthia_carpenter', 'gary_brooks')
# (2023, 2023) dna_translation ('lauren_ramirez', 'sean_foster')
# (1935, 2023) dna_translation ('carl_rollins', 'cynthia_carpenter')
# (1935, 2023) dna_translation ('susan_short', 'jason_smith')
# (1935, 2023) dna_translation ('vincent_clark', 'jaime_rodriguez')
# (1935, 2023) dna_translation ('wesley_molina', 'melissa_mclean')
# (1935, 2023) dna_translation ('amanda_white', 'kevin_wade')
# (1935, 2023) dna_translation ('sierra_lee', 'michael_stewart')
# (1935, 2023) dna_translation ('diana_alexander', 'rebecca_russo')
# (1935, 2023) what_sort_of_sorcery_is_this ('jessica_carter', 'jacqueline_middleton')
# (1935, 2023) what_sort_of_sorcery_is_this ('lynn_hall', 'jacqueline_middleton')
# (1935, 2023) what_sort_of_sorcery_is_this ('thomas_harris', 'jacqueline_middleton')
# (1935, 2023) what_sort_of_sorcery_is_this ('kimberly_smith', 'jacqueline_middleton')
# (1935, 2023) what_sort_of_sorcery_is_this ('margaret_santiago', 'jacqueline_middleton')
# (1935, 2023) what_sort_of_sorcery_is_this ('shelley_wells', 'regina_bowman')
# (1935, 2023) kochize ('kara_medina', 'jennifer_li')
# (1935, 2023) kochize ('jared_johnson', 'jennifer_li')
# (1935, 2023) kochize ('andrew_perez', 'jennifer_li')
# (1935, 2023) kochize ('katherine_benson', 'jennifer_li')
# (1935, 2023) to_infinity_and_beyond ('kevin_kelly', 'deanna_perry')
# (1935, 2023) to_infinity_and_beyond ('kristina_wilcox', 'deanna_perry')
# (1935, 2023) to_infinity_and_beyond ('leslie_moreno', 'deanna_perry')
# (1935, 2023) to_infinity_and_beyond ('laura_waller', 'deanna_perry')
# (1935, 2023) to_infinity_and_beyond ('james_long', 'deanna_perry')
# (1935, 2023) to_infinity_and_beyond ('ashley_rogers', 'deanna_perry')
# (1821, 2023) to_infinity_and_beyond ('william_moreno', 'deanna_perry')
# (2023, 2023) to_infinity_and_beyond ('jennifer_washington', 'deanna_perry')
# (1935, 2023) to_infinity_and_beyond ('jennifer_washington', 'deanna_perry')
# (1821, 2023) to_infinity_and_beyond ('rhonda_randall', 'deanna_perry')
# (1935, 2023) dragonize ('shannon_ford', 'edward_collier')
# (1935, 2023) dragonize ('christopher_gilmore', 'edward_collier')
# (1935, 2023) dragonize ('david_washington', 'edward_collier')
# (1935, 2023) dragonize ('tim_hoffman', 'edward_collier')
# (1935, 2023) dragonize ('walter_johnson', 'edward_collier')
# (1935, 2023) dragonize ('carlos_terry', 'edward_collier')
# (1935, 2023) dragonize ('jesse_perry', 'edward_collier')
# (1935, 2023) dragonize ('sonya_bowers', 'edward_collier')
# (1935, 2023) dragonize ('paula_guerrero', 'edward_collier')
# (1935, 2023) dragonize ('laura_salazar', 'edward_collier')
# (1935, 2023) dragonize ('luis_armstrong', 'edward_collier')
# (1935, 2023) dragonize ('anne_thompson', 'edward_collier')
# (1935, 2023) dragonize ('traci_rowland', 'edward_collier')
# (1935, 2023) dragonize ('vanessa_camacho', 'edward_collier')
# (1821, 2023) dragonize ('mr._ryan_sanchez', 'edward_collier')
# (1935, 2023) 2048_solver ('carl_rollins', 'timothy_tucker')
# (1935, 2023) 2048_solver ('alexa_hernandez', 'timothy_tucker')
# (2023, 2023) 2048_solver ('timothy_tucker', 'sandra_thompson')
# (1821, 2023) 2048_solver ('cindy_howard', 'timothy_tucker')
# (1821, 2023) 2048_solver ('elizabeth_perry', 'timothy_tucker')
# (1935, 2023) 2048_solver ('alexa_hernandez', 'alexander_wells')
# (1935, 2023) 2048_solver ('carol_harris', 'robert_barton')
# (2023, 2023) 2048_solver ('sandra_thompson', 'robert_barton')
# (1821, 2023) 2048_solver ('tanner_garner', 'robert_barton')
# (1935, 2023) 2048_solver ('frank_burns', 'timothy_tucker')
# (1935, 2023) 2048_solver ('cynthia_dougherty', 'robert_barton')
# (2023, 2023) 2048_solver ('michael_stewart', 'robert_barton')
# (1935, 2023) 2048_solver ('frank_burns', 'robert_barton')
# (1935, 2023) 2048_solver ('anthony_stephens', 'robert_barton')
# (1821, 2023) facebook_stalkers ('jessica_torres', 'regina_martinez')
# (1821, 2023) facebook_stalkers ('joseph_tapia', 'timothy_tucker')
# (1935, 2023) facebook_stalkers ('patricia_reeves', 'regina_martinez')
# (1821, 2023) facebook_stalkers ('luis_hansen', 'karen_harris')
# (1935, 2023) facebook_stalkers ('christopher_mendoza', 'regina_martinez')
# (1821, 2023) facebook_stalkers ('ivan_kramer', 'regina_martinez')
# (1935, 2023) facebook_stalkers ('richard_hubbard', 'timothy_tucker')
# (1935, 2023) facebook_stalkers ('mikayla_nelson', 'timothy_tucker')
# (1935, 2023) facebook_stalkers ('michael_marsh', 'michelle_owens')
# (1935, 2023) 2048_game ('patricia_baker', 'john_cuevas_md')
# (1935, 2023) 2048_game ('traci_rowland', 'matthew_barnes')
# (1935, 2023) hungry_games_training_part_iii ('cassandra_hernandez', 'casey_phillips')
# (1821, 2023) hungry_games_training_part_iii ('sarah_lopez', 'casey_phillips')
# (1935, 2023) hungry_games_training_part_iii ('sonya_bowers', 'megan_james')
# (1821, 2023) hungry_games_training_part_iii ('michael_fitzgerald', 'dale_fox')
# (1935, 2023) hungry_games_training_part_iii ('christopher_anderson', 'casey_phillips')
# (1935, 2023) hungry_games_training_part_iii ('amanda_morgan', 'karen_harris')
# (1935, 2023) hungry_games_training_part_iii ('kevin_houston', 'michelle_smith')
# (2023, 2023) more_than_thrice ('tony_johnson', 'david_clark')
# (1821, 2023) more_than_thrice ('john_gordon', 'david_clark')
# (1935, 2023) hungry_games_training_part_i ('amy_miller', 'brian_elliott')
# (1935, 2023) hungry_games_training_part_i ('megan_lopez', 'jennifer_cox')
# (1935, 2023) hungry_games_training_part_i ('amy_miller', 'gary_brooks')
# (1821, 2023) hungry_games_training_part_i ('makayla_mitchell', 'jennifer_cox')
# (1935, 2023) hungry_games_training_part_i ('zachary_austin', 'gary_brooks')
# (1821, 2023) hungry_games_training_part_i ('monica_carr', 'marc_key')
# (1821, 2023) hungry_games_training_part_i ('jerry_bradley_md', 'megan_james')
# (1935, 2023) hungry_games_training_part_i ('stephanie_johnson', 'jennifer_cox')
# (1935, 2023) hungry_games_training_part_i ('andrew_black', 'jennifer_cox')
# (1821, 2023) hungry_games_training_part_i ('lisa_russell', 'jennifer_cox')
# (1935, 2023) hungry_games_training_part_i ('julia_jones', 'brian_elliott')
# (1935, 2023) hungry_games_training_part_i ('hayley_moore', 'brian_elliott')
# (1821, 2023) hungry_games_training_part_i ('sherri_hart', 'brian_elliott')
# (1821, 2023) hungry_games_training_part_i ('kayla_nolan', 'brian_elliott')
# (1821, 2023) hungry_games_training_part_i ('benjamin_jones', 'jennifer_cox')
# (1935, 2023) hungry_games_training_part_i ('lindsay_moore', 'lisa_powell')
# (1935, 2023) hungry_games_training_part_i ('deborah_taylor', 'lisa_powell')
# (1935, 2023) hungry_games_training_part_i ('zachary_austin', 'brian_elliott')
# (1935, 2023) hungry_games_training_part_i ('patricia_reeves', 'brian_elliott')
# (1821, 2023) hungry_games_training_part_i ('brian_olsen', 'brian_elliott')
# (1821, 2023) hungry_games_training_part_i ('luis_robertson', 'casey_phillips')
# (1821, 2023) hungry_games_training_part_i ('joseph_snyder', 'brian_elliott')
# (2023, 2023) hungry_games_training_part_i ('gary_brooks', 'brian_elliott')
# (1935, 2023) hungry_games_training_part_i ('julia_jones', 'gary_brooks')
# (1935, 2023) hungry_games_training_part_i ('raymond_allen', 'gary_brooks')
# (1935, 2023) hungry_games_training_part_i ('raymond_allen', 'brian_elliott')
# (1935, 2023) hungry_games_training_part_i ('hayley_moore', 'gary_brooks')
# (1821, 2023) hungry_games_training_part_ii ('michael_adams', 'thomas_barnes')
# (1821, 2023) hungry_games_training_part_ii ('mary_cooper', 'thomas_barnes')
# (1935, 2023) hungry_games_training_part_ii ('trevor_ford', 'thomas_barnes')
# (1935, 2023) hungry_games_training_part_ii ('amber_bennett', 'thomas_barnes')
# (1935, 2023) hungry_games_training_part_ii ('jerry_garcia', 'thomas_barnes')
# (1935, 2023) hungry_games_training_part_ii ('raymond_allen', 'thomas_barnes')
# (1935, 2023) hungry_games_training_part_ii ('albert_turner', 'thomas_barnes')
# (1935, 2023) hungry_games_training_part_ii ('nicole_stewart', 'thomas_barnes')
# (1821, 2023) hungry_games_training_part_ii ('patrick_saunders', 'thomas_barnes')
# (1821, 2023) hungry_games_training_part_ii ('diana_stone', 'thomas_barnes')
# (1935, 2023) hungry_games_training_part_ii ('andrew_grimes', 'thomas_barnes')
# (1935, 2023) hungry_games_training_part_ii ('pamela_kelley', 'thomas_barnes')
# (1821, 2023) hungry_games_training_part_ii ('daniel_levine', 'thomas_barnes')
# (1935, 2023) hungry_games_training_part_ii ('jennifer_aguilar', 'thomas_barnes')
# (1821, 2023) hungry_games_training_part_ii ('katie_alexander', 'thomas_barnes')
# (1935, 2023) hungry_games_training_part_ii ('luis_armstrong', 'thomas_barnes')
# (1935, 2023) hungry_games_training_part_ii ('rachel_martin', 'thomas_barnes')
# (1935, 2023) diagnostics ('justin_burton', 'eugene_ibarra')
# (1935, 2023) diagnostics ('thomas_harris', 'eugene_ibarra')
# (2023, 2023) diagnostics ('eugene_ibarra', 'rebecca_russo')
# (1821, 2023) diagnostics ('matthew_cohen', 'eugene_ibarra')

# %%
## Group and Rank by missions

grouped_moss_data = moss_data.groupby(["mission"])
mission_titles = grouped_moss_data['mission'].unique().index.tolist()
max_rank = dict(zip(grouped_moss_data['Moss Rank'].max().index, grouped_moss_data['Moss Rank'].max()))
mission_averages = grouped_moss_data['standardised1'].mean()
sorted_averages = sorted(zip(mission_averages.index, mission_averages), key=lambda x: x[1])
normalized_averages = dict(map(lambda x: (x[0], 1/x[1]), sorted_averages))

# %%
## Plot of Rank and Similarities

import numpy as np
import matplotlib.pyplot as plt

figure, ax = plt.subplots(nrows=7, ncols=4, figsize=[20, 20])
plt.setp(ax, xticks=[i for i in range(0, 151, 10)],
        yticks=[i for i in range(0, 101, 10)])
counter = 0
for name, group in grouped_moss_data:
    row, col = counter%7, counter%4
    x = np.array(group['Moss Rank'].tolist())
    y = np.array(group['standardised1'].tolist())
    ax[row, col].plot(x,y)
    ax[row, col].title.set_text('{}'.format(name))
    counter+=1
figure.tight_layout()

# %%
## Slice points by MOSS Rank

def points_aggregation(moss_rank, max_rank, points):
    return math.exp(-(moss_rank)/max_rank)*points

def obtain_points(moss_rank, mission, mrank, raverages):
    _max_rank = mrank[mission]
    points = raverages[mission]
    return points_aggregation(moss_rank, _max_rank, points)

moss_data['Points'] = moss_data.apply(lambda x: obtain_points(x['Moss Rank'], x['mission'], max_rank, normalized_averages), axis=1)

# %%
percentile_pairs = {}
for pairs in sorted_pairs:
    a = moss_data[(moss_data['name1'] == pairs[0]) & (moss_data['name2'] == pairs[1])]['Points'].sum()
    b = moss_data[(moss_data['name2'] == pairs[0]) & (moss_data['name1'] == pairs[1])]['Points'].sum()
    percentile_pairs[pairs] = a+b

# %%
# def normalizer(x, values):
#     maxx = max(values)
#     minn = min(values)
#     return (x-minn)/(maxx-minn)

# percentiles = dict(map(lambda x: (x[0], normalizer(x[1], percentile_pairs.values())), percentile_pairs.items()))

# %%
## Export from pandas to CSV

export_data = pd.DataFrame([], columns=['NodeID1', 'NodeID2', 'edge_weights'])
for pair in sorted_pairs:
    export_data=export_data.append({'NodeID1':pair[0], 'NodeID2':pair[1], 'edge_weights':percentile_pairs[pair]}, ignore_index=True)
    
export_data.to_csv('{}_edge_weights.csv'.format(method_name), index=False)

# %%
export_data.shape

# %%
len(set(export_data.NodeID1.tolist() + export_data.NodeID2.tolist())), len(set(list(map(lambda x: x[0], sorted_pairs)) + list(map(lambda x: x[1], sorted_pairs))))
# Out:
# (1030, 1030)

# %%
folder_directory = '/Users/leonard.lee/Downloads/CS5340_Project/true_labels'
file_name = '2023.csv'
# file_name = '1935.csv'
# file_name = '1821.csv'

tl_folder = os.path.join(folder_directory, file_name)

# %%
tl_data = pd.read_csv(tl_folder)

# %%
tl_data
# Out:
#              Timestamp                 Name  \
# 0   3/17/2021 22:35:08           jeff_hines
# 1   3/17/2021 22:49:50         meagan_boyle
# 2   3/17/2021 22:58:36      timothy_francis
# 3   3/17/2021 23:00:19  johnathan_velazquez
# 4   3/17/2021 23:41:30      steven_campbell
# 5    3/18/2021 0:28:59          gary_brooks
# 6    3/18/2021 2:59:19          harold_ryan
# 7    3/18/2021 3:06:23     franklin_carlson
# 8    3/18/2021 7:26:48        haley_patrick
# 9   3/18/2021 10:48:40             marc_key
# 10  3/18/2021 12:24:48     jennifer_simmons
# 11  3/18/2021 12:29:32     jennifer_simmons
# 12  3/18/2021 12:36:39     jennifer_simmons
# 13  3/18/2021 13:04:23     jennifer_simmons
# 14  3/18/2021 13:09:08       casey_phillips
# 15  3/18/2021 13:44:10         karen_harris
# 16  3/18/2021 14:12:36        carol_garrett
# 17  3/18/2021 14:18:11    cynthia_carpenter
# 18  3/18/2021 17:16:33          cody_torres
# 19  3/18/2021 18:31:58         james_church
# 20  3/18/2021 19:11:24         pamela_colon
# 21  3/18/2021 22:37:57     maureen_morrison
# 22  3/18/2021 22:44:21       sierra_montoya
# 23  3/18/2021 22:53:58     veronica_collier
# 24  3/18/2021 22:56:08       edward_collier
# 25  3/18/2021 23:51:45        joshua_branch
# 26   3/19/2021 0:00:45       andrew_sanders
# 27   3/19/2021 0:01:45         jose_kennedy
# 28   3/19/2021 0:04:55       andrew_sanders
# 29   3/19/2021 0:42:10         david_harris
# 30   3/19/2021 0:44:04         david_harris
# 31   3/19/2021 0:55:03       kelsey_ramirez
# 32   3/19/2021 1:56:06         david_harris
# 33   3/19/2021 9:18:28           kevin_wade
# 34  3/19/2021 13:32:40          sean_foster
# 35  3/19/2021 16:59:21           jeff_hines
# 36  3/19/2021 17:12:06            eric_ford
# 37  3/19/2021 17:12:25         deanna_perry
# 38  3/19/2021 17:31:18        brian_elliott
# 39  3/19/2021 17:38:26     maureen_morrison
# 40  3/19/2021 17:38:57  johnathan_velazquez
# 41  3/19/2021 18:08:17       peter_callahan
# 42  3/19/2021 18:38:00         deanna_perry
# 43  3/19/2021 18:42:03         deanna_perry
# 44  3/19/2021 19:52:35       edward_collier
# 45  3/19/2021 20:15:43       mary_clark_dds
# 46  3/19/2021 20:36:03        eugene_nelson
# 47  3/19/2021 22:06:16         deanna_perry
# 48  3/19/2021 22:48:26       casey_phillips
# 49  3/19/2021 22:50:25          lisa_powell
# 50  3/19/2021 23:50:44    frederick_jimenez
# 51  3/19/2021 23:58:36         jared_carter
# 52  3/19/2021 23:58:54           jill_sharp
# 53  3/19/2021 23:58:58           jeff_hines
# 54   3/26/2021 2:45:01        michael_smith
# 55   3/26/2021 3:22:11          harold_ryan
# 56  3/26/2021 18:21:38         ricky_torres
# 57  3/29/2021 21:03:19       patricia_brown
#
#    Please indicate your tutorial group  \
# 0                                  T32
# 1                                  T34
# 2                                  T21
# 3                                  T35
# 4                                  T09
# 5                                  T27
# 6                                  T23
# 7                                  T33
# 8                                  T24
# 9                                  T25
# 10                                 T17
# 11                                 T17
# 12                                 T17
# 13                                 T17
# 14                                 T01
# 15                                 T06
# 16                                 T31
# 17                                 T02
# 18                                 T22
# 19                                 T14
# 20                                 T12
# 21                                 T25
# 22                                 T35
# 23                                 T10
# 24                                 T07
# 25                                 T36
# 26                                 T24
# 27                                 T17
# 28                                 T24
# 29                                 T07
# 30                                 T07
# 31                                 T06
# 32                                 T07
# 33                                 T24
# 34                                 T30
# 35                                 T32
# 36                                 T07
# 37                                 T18
# 38                                 T29
# 39                                 T25
# 40                                 T35
# 41                                 T24
# 42                                 T18
# 43                                 T18
# 44                                 T07
# 45                                 T28
# 46                                 T25
# 47                                 T18
# 48                                 T01
# 49                                 T28
# 50                                 T37
# 51                                 T01
# 52                                 T11
# 53                                 T32
# 54                                 T23
# 55                                 T23
# 56                                 T23
# 57                                 T10
#
#                       Please indicate the assignments  \
# 0   runic_painting,magic_efficiency,curve_introduc...
# 1                  rogue_train,to_infinity_and_beyond
# 2                                         rogue_train
# 3                           lazy_susan,3_station_ippt
# 4   curve_introduction,curve_manipulation,rogue_train
# 5                                         rogue_train
# 6                   advanced_spells,kochize,dragonize
# 7               circle_manipulation,kochize,dragonize
# 8                          rogue_train,3_station_ippt
# 9                                  curve_manipulation
# 10                                        rogue_train
# 11                                        rogue_train
# 12                                        rogue_train
# 13                                        rogue_train
# 14                        advanced_spells,rogue_train
# 15                                  funky_merge_spell
# 16  advanced_spells,curve_manipulation,circle_mani...
# 17                      rogue_train,cheryl_s_birthday
# 18  circle_manipulation,rogue_train,to_infinity_an...
# 19                                kochize,rogue_train
# 20                                        rogue_train
# 21  magic_efficiency,curve_manipulation,rogue_trai...
# 22                                        rogue_train
# 23                             to_infinity_and_beyond
# 24                                        rogue_train
# 25                                     3_station_ippt
# 26                                        rogue_train
# 27                                        rogue_train
# 28                                        rogue_train
# 29  runic_painting,curve_introduction,curve_manipu...
# 30  runic_painting,curve_introduction,curve_manipu...
# 31                                        rogue_train
# 32  runic_painting,cyclic_runes,curve_introduction...
# 33                                     3_station_ippt
# 34  curve_manipulation,circle_manipulation,rogue_t...
# 35  runic_painting,magic_efficiency,curve_introduc...
# 36                                     3_station_ippt
# 37  runic_painting,cyclic_runes,more_than_thrice,c...
# 38                                        rogue_train
# 39  runic_painting,cyclic_runes,advanced_spells,ma...
# 40                                       cyclic_runes
# 41  curve_introduction,curve_manipulation,rogue_tr...
# 42  cyclic_runes,advanced_spells,more_than_thrice,...
# 43  cyclic_runes,more_than_thrice,curve_introducti...
# 44                  curve_manipulation,3_station_ippt
# 45                                            kochize
# 46                                     3_station_ippt
# 47  more_than_thrice,curve_introduction,curve_mani...
# 48                            writing_a_sorting_spell
# 49                                        rogue_train
# 50                      rogue_train,funky_merge_spell
# 51                         rogue_train,3_station_ippt
# 52  curve_introduction,curve_manipulation,circle_m...
# 53  runic_painting,magic_efficiency,more_than_thri...
# 54                        runic_painting,cyclic_runes
# 55  advanced_spells,curve_introduction,curve_manip...
# 56  curve_manipulation,kochize,rogue_train,3_stati...
# 57             curve_manipulation,kochize,rogue_train
#
#                                       Indicate source  \
# 0   https://github.com/khoo0030/cs1010x\nhttps://g...
# 1                  https://github.com/chunmun/CS1010S
# 2   https://github.com/chunmun/CS1010S/blob/master...
# 3   https://stackoverflow.com/questions/49165175/p...
# 4                  https://github.com/chunmun/CS1010S
# 5                                   Janevy (This sem)
# 6         Chrus Chong, I believe he did this as IBLOC
# 7                                        Jun Jie Sem1
# 8                  https://github.com/chunmun/CS1010S
# 9   https://github.com/tanteidaiko/CS1010S-AY1819S...
# 10  https://github.com/chunmun/CS1010S/tree/master...
# 11  https://github.com/chunmun/CS1010S/tree/master...
# 12  https://github.com/chunmun/CS1010S/tree/master...
# 13  https://github.com/chunmun/CS1010S/tree/master...
# 14  Side Quest 2.1: https://www.coursehero.com/fil...
# 15  I stored all the sorting and searching codes i...
# 16  https://github.com/chunmun/CS1010S\nhttps://gi...
# 17                https://github.com/chunmun/CS1010S
# 18                                 www.coursehero.com
# 19                      Koh Han Wei(past 2 or 3 sems)
# 20  Like discuss with my friends only cos that wee...
# 21                 https://github.com/chunmun/CS1010S
# 22                               Irwin Tay Khai Cheng
# 23  https://github.com/chunmun/CS1010S/blob/master...
# 24  https://github.com/chunmun/CS1010S/blob/master...
# 25                 Chrus Chong. CS1010X iBLOC 2020(?)
# 26  https://stackoverflow.com/questions/44596077/d...
# 27  https://github.com/chunmun/CS1010S/blob/master...
# 28  https://github.com/chunmun/CS1010S/blob/master...
# 29  https://github.com/ptdzung/Static_Orbital/tree...
# 30  https://github.com/ptdzung/Static_Orbital/tree...
# 31                         Ryan Walter Lee (this sem)
# 32                  https://github.com/mclsun/CS1010X
# 33  https://github.com/chunmun/CS1010S/blob/master...
# 34                 https://github.com/chunmun/CS1010S
# 35  https://github.com/khoo0030/cs1010x/blob/maste...
# 36  Asked for help from my cousin and later found ...
# 37                                Friends and Seniors
# 38  https://www.coursehero.com/file/59046636/missi...
# 39  https://github.com/chunmun/CS1010S and Arnav G...
# 40                            Ngo Si Tong, 2019 Sem 1
# 41  Mission 4:\nhttps://github.com/gluonn/etc/blob...
# 42  https://stackoverflow.com/questions/49110391/p...
# 43         Codes are sent in the previous submission.
# 44  https://github.com/chunmun/CS1010S/blob/master...
# 45  For Task 2: https://github.com/chunmun/CS1010S...
# 46  https://github.com/tanteidaiko/CS1010S-AY1819S...
# 47                 https://github.com/chunmun/CS1010S
# 48  Task 4(b) : https://www.coursehero.com/file/pn...
# 49  https://github.com/chunmun/CS1010S/blob/master...
# 50  https://www.coursehero.com/profile/linyijun24/...
# 51                 https://github.com/chunmun/CS1010S
# 52                  Huang Xilin, AY2020/21 Semester 1
# 53  https://github.com/khoo0030/cs1010x/blob/maste...
# 54              Seraphina Chia, took in Sem 2 last AY
# 55                         Chrus Chong, CS1010X IBLOC
# 56                        Koh Tze Kang, AY20/21 Sem 1
# 57                 https://github.com/chunmun/CS1010S
#
#     Is there anything else you would like us to know?
# 0   I guess I was just tempted to cheat cause of t...
# 1   For mission 7, not all from the source but onl...
# 2                                                 NaN
# 3   For Lazy Susan Q5, I searched online to get so...
# 4                                                 NaN
# 5   I wish to emphasize that she did not send me h...
# 6                                                 NaN
# 7   Couldnt visualize the code on Pythontutor so i...
# 8   I sincerely apologise for cheating. It was dur...
# 9   There were 3 missions due that week so I had t...
# 10  i am so sorry for my actions. no matter how ch...
# 11  i am so sorry for my actions. no matter how ch...
# 12  i am so sorry for my actions. i only reference...
# 13  i am so sorry for my actions. i only reference...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  I referred to the online source for help and I...
# 19                   I asked to see code to reference
# 20                                                NaN
# 21  I faced a lot of challenges and problems throu...
# 22                                 Discussed together
# 23  Was confused and frustrated with questions and...
# 24                                                NaN
# 25  I only referred to his code for the data parsi...
# 26  I wasn't sure how to do the datetime thing for...
# 27  I deeply apologize for this incident as I was ...
# 28  im so sorry i copied the wrong link !! this is...
# 29  I am sorry and really ashamed of my wrongdoing...
# 30  I am sorry and really ashamed of my wrongdoing...
# 31     We were discussing and shared the same answer.
# 32                                                NaN
# 33  for my mission 8 qn 1, I was stuck on it for v...
# 34  I came across the GitHub link, and used it for...
# 35  I confessed earlier and I am not sure whether ...
# 36  I have emailed Prof about this. It really was ...
# 37  Dear Mr. Jonathan Chen, Ms. Esther\n\nHello.\n...
# 38                                                NaN
# 39  I had access to Arnav's account last semester,...
# 40  Asked her for help for q4 as I knew how to do ...
# 41                                                NaN
# 42  I have sent multiple emails indicating that I ...
# 43  I have sent multiple emails indicating that I ...
# 44                                                NaN
# 45  For task 2:\nI am not very sure if this counts...
# 46  I only took a glance for the first part becaus...
# 47  I will do my best to get a "C" and S/U it.\nI ...
# 48                                                NaN
# 49  I was done with all the previous parts, but I ...
# 50  Not sure if what i have submitted is plagiaris...
# 51  Did the assignment on my own first; knew about...
# 52  I regret deeply and am willing to own up to th...
# 53  I cross- checked and I think this is all the m...
# 54  I received help from her for Missions 2 and Si...
# 55  For Side Quest 8.2, I do not think this was pl...
# 56                                                NaN
# 57  I apologise for this late submission as I have...

# %%
## Task 2 & 3 (Check Moss Results)

def checker(name):
    if name in name_to_ID.keys():
        return name_to_ID[name]
    return 'Name Not Found Error'

labels = tl_data[['Name', 'Please indicate the assignments']]
labels['ID'] = labels['Name'].apply(lambda x: checker(x))
names_not_found = labels[labels['ID'] == 'Name Not Found Error']
# Out:
# /Users/leonard.lee/miniconda3/envs/jupyter/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
labels.head(n=30)
# Out:
#                    Name                    Please indicate the assignments  \
# 0            jeff_hines  runic_painting,magic_efficiency,curve_introduc...
# 1          meagan_boyle                 rogue_train,to_infinity_and_beyond
# 2       timothy_francis                                        rogue_train
# 3   johnathan_velazquez                          lazy_susan,3_station_ippt
# 4       steven_campbell  curve_introduction,curve_manipulation,rogue_train
# 5           gary_brooks                                        rogue_train
# 6           harold_ryan                  advanced_spells,kochize,dragonize
# 7      franklin_carlson              circle_manipulation,kochize,dragonize
# 8         haley_patrick                         rogue_train,3_station_ippt
# 9              marc_key                                 curve_manipulation
# 10     jennifer_simmons                                        rogue_train
# 11     jennifer_simmons                                        rogue_train
# 12     jennifer_simmons                                        rogue_train
# 13     jennifer_simmons                                        rogue_train
# 14       casey_phillips                        advanced_spells,rogue_train
# 15         karen_harris                                  funky_merge_spell
# 16        carol_garrett  advanced_spells,curve_manipulation,circle_mani...
# 17    cynthia_carpenter                      rogue_train,cheryl_s_birthday
# 18          cody_torres  circle_manipulation,rogue_train,to_infinity_an...
# 19         james_church                                kochize,rogue_train
# 20         pamela_colon                                        rogue_train
# 21     maureen_morrison  magic_efficiency,curve_manipulation,rogue_trai...
# 22       sierra_montoya                                        rogue_train
# 23     veronica_collier                             to_infinity_and_beyond
# 24       edward_collier                                        rogue_train
# 25        joshua_branch                                     3_station_ippt
# 26       andrew_sanders                                        rogue_train
# 27         jose_kennedy                                        rogue_train
# 28       andrew_sanders                                        rogue_train
# 29         david_harris  runic_painting,curve_introduction,curve_manipu...
#
#                       ID
# 0                    411
# 1                    686
# 2                    978
# 3                    485
# 4   Name Not Found Error
# 5                    325
# 6                    348
# 7                    318
# 8                    342
# 9                    644
# 10                   432
# 11                   432
# 12                   432
# 13                   432
# 14                   150
# 15                   535
# 16                   142
# 17                   208
# 18                   187
# 19                   377
# 20                   782
# 21                   684
# 22                   930
# 23                  1001
# 24                   281
# 25                   516
# 26                    59
# 27                   504
# 28                    59
# 29                   237

# %%
names_not_found
# Out:
#                Name                    Please indicate the assignments  \
# 4   steven_campbell  curve_introduction,curve_manipulation,rogue_train
# 36        eric_ford                                     3_station_ippt
#
#                       ID
# 4   Name Not Found Error
# 36  Name Not Found Error

# %%
names_not_found.to_csv('missing_names_'+file_name, index=False)

# %%
## Task 4 (NetworkX)

# %%
## Task 5 (Edge_Index)

pattern = re.compile(r'(match[0-9]+).html')

edge_index = pd.DataFrame([], columns=['nodeid', 'mission', 'moss_ranking', 'edge_weights'])
for name in tqdm(all_names):
    idee = name_to_ID[name]
    relevant_rows = moss_data[(moss_data.name1 == name) | (moss_data.name2 == name)]
    for index, item in relevant_rows.iterrows():
        edge_index = edge_index.append({'nodeid': idee, 
                                        'mission': item.mission, 
                                        'moss_ranking': pattern.search(item.url)[0][5:-5], 
                                        }, ignore_index=True)
# Out:
# 100%|██████████| 1032/1032 [00:25<00:00, 40.38it/s]

# %%
relevant_rows.head()
# Out:
#                mission  cohort1  assessment1  submission1            name1  \
# 510  funky_merge_spell     1821        33174       952434  morgan_williams
# 904         lazy_susan     1821        33173       951628  morgan_williams
# 909         lazy_susan     1821        33173       951628  morgan_williams
# 912         lazy_susan     1821        33173       951628  morgan_williams
# 916         lazy_susan     1821        33173       912554    michael_gomez
#
#      cohort2  assessment2  submission2                name2  percent1  \
# 510     1935        38725      1059628           james_long        54
# 904     2023        41931      1170102  jennifer_washington        91
# 909     1935        38724      1048729        kenneth_allen        74
# 912     1935        38724      1062843         corey_bender        63
# 916     1821        33173       951628      morgan_williams        59
#
#      percent2  lines                                                url
# 510        50     50  http://moss.stanford.edu/results/9/55540043683...
# 904        90    103  http://moss.stanford.edu/results/0/56645335735...
# 909        77     93  http://moss.stanford.edu/results/0/56645335735...
# 912        69     92  http://moss.stanford.edu/results/0/56645335735...
# 916        61     49  http://moss.stanford.edu/results/0/56645335735...

# %%
edge_index.head()
# Out:
#   NodeID                       Mission MOSS Ranking
# 0    822               dna_translation           11
# 1    822               dna_translation           67
# 2    822               dna_translation          126
# 3    822  what_sort_of_sorcery_is_this          116
# 4    822                       kochize           10
